# %% [markdown]
# <a href="https://colab.research.google.com/github/SIMBL742/GridironGenius/blob/main/GridironGenius_ModelA_TitansD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import Libraries**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # **Load Data**

# %%
df = pd.read_csv('https://raw.githubusercontent.com/SIMBL742/GridironGenius/refs/heads/main/dataset_2024-2025_TitansD_QBP_.csv')
df
# Out:
#    Passing Yards  Passing Touchdowns  Rushing Touchdowns  Rushing Yards   Y/C  \
# 0           3.72                   0                   0            1.5   6.6
# 1           7.04                   8                   0            0.1   9.8
# 2           8.08                   4                   6            7.3  15.5
# 3           3.40                   0                   0            0.0   6.9
# 4           7.56                   8                   0            0.1   8.6
# 5          13.92                   8                   0            0.1  15.4
#
#    ANY/A  Pressures  Fantasy Points
# 0   2.06      0.242            7.22
# 1   6.38      0.121           15.14
# 2   9.55      0.120           25.38
# 3   3.25      0.231           11.84
# 4   4.84      0.128           14.66
# 5  10.44      0.114           22.02

# %% [markdown]
# # **Define X and Y**

# %%
X = df.drop('Fantasy Points', axis=1)
y = (df['Fantasy Points'] >= 20).astype(int)  # 1 for boom (>= 20 points), 0 for bust (< 20 points)

# %%
X
# Out:
#    Passing Yards  Passing Touchdowns  Rushing Touchdowns  Rushing Yards   Y/C  \
# 0           3.72                   0                   0            1.5   6.6
# 1           7.04                   8                   0            0.1   9.8
# 2           8.08                   4                   6            7.3  15.5
# 3           3.40                   0                   0            0.0   6.9
# 4           7.56                   8                   0            0.1   8.6
# 5          13.92                   8                   0            0.1  15.4
#
#    ANY/A  Pressures
# 0   2.06      0.242
# 1   6.38      0.121
# 2   9.55      0.120
# 3   3.25      0.231
# 4   4.84      0.128
# 5  10.44      0.114

# %%
y
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    0
# 5    1
# Name: Fantasy Points, dtype: int64

# %% [markdown]
# # **Split Train and Test Data**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1, random_state=100)

# %%
X_train
# Out:
#    Passing Yards  Passing Touchdowns  Rushing Touchdowns  Rushing Yards   Y/C  \
# 2           8.08                   4                   6            7.3  15.5
# 4           7.56                   8                   0            0.1   8.6
# 3           3.40                   0                   0            0.0   6.9
# 5          13.92                   8                   0            0.1  15.4
# 0           3.72                   0                   0            1.5   6.6
#
#    ANY/A  Pressures
# 2   9.55      0.120
# 4   4.84      0.128
# 3   3.25      0.231
# 5  10.44      0.114
# 0   2.06      0.242

# %%
X_test
# Out:
#    Passing Yards  Passing Touchdowns  Rushing Touchdowns  Rushing Yards  Y/C  \
# 1           7.04                   8                   0            0.1  9.8
#
#    ANY/A  Pressures
# 1   6.38      0.121

# %% [markdown]
# # **Scale the features**

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # **Initialize the RandomForestClassifier**

# %%
model = RandomForestClassifier(n_estimators=7, random_state=100)

# %% [markdown]
# # **Fit Model the training data**

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=7, random_state=100)

# %% [markdown]
# # **Predictions on test set**

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# # **Load Player Data**

# %%
df_player_data = pd.read_csv('https://raw.githubusercontent.com/SIMBL742/GridironGenius/refs/heads/main/dataset_2024-2025_QBs.csv')
df_player_data
# Out:
#    First Name        Last Name  Passing Yards  Passing Touchdowns  \
# 0        Geno            Smith          11.77                4.50
# 1       Baker         Mayfield          11.05               10.29
# 2       Brock            Purdy          10.66                5.14
# 3        Kirk          Cousins          10.88                5.71
# 4       Lamar          Jackson          10.60                8.57
# 5         Joe           Burrow          10.33                8.00
# 6       Aaron          Rodgers           9.50                5.71
# 7        C.J.           Stroud           9.79                5.71
# 8       Jared             Goff          11.07                6.66
# 9         Dak         Prescott           7.31                5.33
# 10     Trevor         Lawrence           8.80                5.14
# 11       Josh            Allen           8.62                6.80
# 12     Daniel            Jones           8.24                3.43
# 13     Jayden          Daniels           9.36                6.00
# 14    Matthew         Stafford           9.45                2.00
# 15    Patrick          Mahomes           9.43                4.00
# 16        Sam          Darnold           9.13                8.00
# 17     Jordan             Love          11.08               12.00
# 18      Kyler           Murray           7.60                5.14
# 19      Caleb         Williams           9.11                6.00
# 20      Jalen            Hurts           8.89                4.67
# 21         Bo              Nix           6.33                3.33
# 22    Gardner          Minshew           7.78                2.67
# 23     Justin          Herbert           7.92                4.00
# 24     Justin           Fields           7.54                3.33
# 25       Andy           Dalton           8.11                5.60
# 26      Derek             Carr           7.91                6.40
# 27    Anthony       Richardson           7.12                3.00
# 28        Joe           Flacco           9.88                9.33
# 29       Will            Levis           6.74                5.00
# 30     Jacoby         Brissett           5.57                1.60
# 31      Drake             Maye          10.38               10.00
# 32        Tua       Tagovailoa          10.16                4.00
# 33      Aidan        O'Connell           5.37                2.67
# 34    Spencer          Rattler           8.30                2.00
# 35      Tyler          Huntley           5.03                1.33
# 36      Malik           Willis           6.48                4.00
# 37      Mason          Rudolph           6.00                2.00
# 38      Bryce            Young           4.90                0.00
# 39    Russell           Wilson          10.56                8.00
# 40     Marcus          Mariota           8.20                8.00
# 41     Jameis          Winston           2.68                0.00
# 42     Dorian  Thomas-Robinson           3.28                0.00
#
#     Rushing Touchdowns  Rushing Yards   Y/C  ANY/A  Pressures  Games Played
# 0                 0.85           2.30  10.4   5.86      0.245             7
# 1                 1.71           2.26  11.3   7.02      0.118             7
# 2                 1.71           2.20  13.3   7.21      0.207             7
# 3                 0.00          -0.11  11.3   6.33      0.219             7
# 4                 1.71           6.64  13.4   9.48      0.170             7
# 5                 0.85           1.30  11.1   7.59      0.159             7
# 6                 0.00           0.16  10.5   5.21      0.189             7
# 7                 0.00           1.34  10.9   6.14      0.290             7
# 8                 0.00           0.28  12.6   8.15      0.225             6
# 9                 1.00           0.42  11.3   5.81      0.265             6
# 10                0.00           1.36  11.7   6.44      0.143             7
# 11                2.57           2.56  12.5   8.42      0.175             7
# 12                0.00           2.63   9.6   4.84      0.249             7
# 13                4.00           5.30  11.1   7.44      0.101             7
# 14                0.00          -0.01  10.5   5.38      0.282             6
# 15                1.00           2.03  10.9   5.50      0.209             6
# 16                0.00           1.66  12.6   7.01      0.267             6
# 17                0.00           0.58  12.3   6.61      0.230             5
# 18                0.29           4.64  10.2   6.34      0.168             7
# 19                0.00           2.82  10.1   5.18      0.198             6
# 20                4.00           3.63  11.3   6.04      0.251             6
# 21                1.71           3.64   9.1   4.57      0.188             7
# 22                0.00           0.67  10.2   4.04      0.227             6
# 23                0.00           0.57  10.9   6.71      0.221             6
# 24                5.00           3.85  10.4   5.89      0.223             6
# 25                0.00           0.68   9.3   4.92      0.162             6
# 26                1.20           0.44  11.0   7.09      0.235             5
# 27                1.50           4.33  16.0   5.17      0.241             5
# 28                0.00           0.87  10.1   6.68      0.154             3
# 29                0.00           2.53   8.4   2.74      0.237             5
# 30                0.00           1.02   8.8   3.84      0.369             5
# 31                0.00           2.80  10.8   5.64      0.177             3
# 32                0.00           1.40  12.1   5.50      0.116             2
# 33                0.00           0.00   8.8   4.44      0.247             4
# 34                0.00           3.05   8.8   3.35      0.217             2
# 35                2.00           2.23   9.7   4.21      0.253             3
# 36                3.00           5.70  13.0   9.16      0.140             3
# 37                0.00           0.65   8.8   4.13      0.274             2
# 38                3.00           0.90   8.1   1.68      0.218             4
# 39                6.00           0.30  16.5  10.00      0.032             1
# 40                0.00           3.40  10.7   8.85      0.138             2
# 41                0.00           0.00  13.8   7.77      0.154             1
# 42                0.00           4.40   7.5  -0.44      0.400             1

# %% [markdown]
# # **Predict Fantasy Player**

# %%
# Define the prediction function using the separate player dataset
def predict_fantasy_player():
    print("\nWelcome to the Gridiron Genius!")

    # Prompt user to input player name
    player_first_name = input("\nEnter the player's first name: ")
    player_last_name = input("Enter the player's last name: ")

    # Check if player exists in the separate player data dataset
    player_info = df_player_data[
        (df_player_data['First Name'] == player_first_name) &
        (df_player_data['Last Name'] == player_last_name)
    ]

    if player_info.empty:
        print(f"\nNo data found for {player_first_name} {player_last_name}. Please check the spelling or ensure the player has sufficient NFL stats.")
        return

    # Link Column Names
    input_data = player_info[X.columns].values
    input_data = pd.DataFrame(input_data, columns=X.columns) # Create DataFrame column names

    # Extract the number of games the player has played
    num_games_played = player_info['Games Played'].values[0]


    input_scaled = scaler.transform(input_data)


    # Make a prediction using the trained model
    prediction = model.predict(input_scaled)
    prediction_label = "BOOM" if prediction[0] == 1 else "BUST"
    print(f"\nGridiron Genius predicts {player_first_name} {player_last_name} will be a {prediction_label} after using data from the last {num_games_played} games.")

# Call the function to predict for a new player
predict_fantasy_player()
# Out:
# Welcome to the Gridiron Genius!
#
# Enter the player's first name: Jared
# Enter the player's last name: Goff
#
# Gridiron Genius predicts Jared Goff will be a BOOM after using data from the last 6 games.
