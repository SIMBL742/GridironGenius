# %% [markdown]
# <a href="https://colab.research.google.com/github/SIMBL742/GridironGenius/blob/main/GridironGenius_ModelA_TitansD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import Libraries**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # **Load Data**

# %%
df = pd.read_csv('https://raw.githubusercontent.com/SIMBL742/GridironGenius/refs/heads/main/dataset_2024-2025_TitansD_QBP_.csv')
df
# Out:
#    Passing Attempts  Passing Completions  Passing Yards  Touchdowns  \
# 0                29                   14             93           0
# 1                30                   18            176           2
# 2                19                   13            202           1
# 3                17                    9             85           0
# 4                38                   22            189           2
#
#    Interceptions  Rushing Attempts  Rushing Touchdowns  Rush Yards  \
# 0              0                 5                   0          15
# 1              0                 2                   0           1
# 2              0                 6                   1          73
# 3              0                 0                   0           0
# 4              1                 1                   0           1
#
#    AVG Rush Yards per Attempt  AVG Time to Throw  AVG  Air Yards Differential  \
# 0                         3.0               2.71                         -5.1
# 1                         0.5               2.45                         -1.0
# 2                        12.2               2.25                         -2.5
# 3                         0.0               2.67                         -0.6
# 4                         1.0               2.80                         -1.1
#
#    Aggressiveness  Average Completed Air Yards  Average Intended Air Yards  \
# 0            10.3                          2.7                         7.8
# 1            23.3                          3.7                         4.8
# 2            15.8                          3.7                         6.2
# 3             5.9                          5.1                         5.7
# 4            13.6                          6.8                         7.9
#
#    Longest Completed Air Distance  Air Yards to the Sticks  Passer Rating  \
# 0                            27.0                     -2.0           55.7
# 1                            37.8                     -4.2           98.8
# 2                            42.3                     -4.1          120.9
# 3                            30.6                     -5.1           67.0
# 4                            54.1                     -0.9          121.3
#
#    Completion Percentage  Fantasy Points
# 0                   48.3            7.22
# 1                   60.0           15.14
# 2                   68.4           25.38
# 3                   52.9           11.84
# 4                   75.0           14.66

# %% [markdown]
# # **Define X and Y**

# %%
X = df.drop('Fantasy Points', axis=1)
y = (df['Fantasy Points'] >= 20).astype(int)  # 1 for boom (>= 15 points), 0 for bust (< 15 points)

# %%
X
# Out:
#    Passing Attempts  Passing Completions  Passing Yards  Touchdowns  \
# 0                29                   14             93           0
# 1                30                   18            176           2
# 2                19                   13            202           1
# 3                17                    9             85           0
# 4                38                   22            189           2
#
#    Interceptions  Rushing Attempts  Rushing Touchdowns  Rush Yards  \
# 0              0                 5                   0          15
# 1              0                 2                   0           1
# 2              0                 6                   1          73
# 3              0                 0                   0           0
# 4              1                 1                   0           1
#
#    AVG Rush Yards per Attempt  AVG Time to Throw  AVG  Air Yards Differential  \
# 0                         3.0               2.71                         -5.1
# 1                         0.5               2.45                         -1.0
# 2                        12.2               2.25                         -2.5
# 3                         0.0               2.67                         -0.6
# 4                         1.0               2.80                         -1.1
#
#    Aggressiveness  Average Completed Air Yards  Average Intended Air Yards  \
# 0            10.3                          2.7                         7.8
# 1            23.3                          3.7                         4.8
# 2            15.8                          3.7                         6.2
# 3             5.9                          5.1                         5.7
# 4            13.6                          6.8                         7.9
#
#    Longest Completed Air Distance  Air Yards to the Sticks  Passer Rating  \
# 0                            27.0                     -2.0           55.7
# 1                            37.8                     -4.2           98.8
# 2                            42.3                     -4.1          120.9
# 3                            30.6                     -5.1           67.0
# 4                            54.1                     -0.9          121.3
#
#    Completion Percentage
# 0                   48.3
# 1                   60.0
# 2                   68.4
# 3                   52.9
# 4                   75.0

# %%
y
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Fantasy Points, dtype: int64

# %% [markdown]
# # **Split Train and Test Data**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1, random_state=100)

# %%
X_train
# Out:
#    Passing Attempts  Passing Completions  Passing Yards  Touchdowns  \
# 2                19                   13            202           1
# 3                17                    9             85           0
# 4                38                   22            189           2
# 0                29                   14             93           0
#
#    Interceptions  Rushing Attempts  Rushing Touchdowns  Rush Yards  \
# 2              0                 6                   1          73
# 3              0                 0                   0           0
# 4              1                 1                   0           1
# 0              0                 5                   0          15
#
#    AVG Rush Yards per Attempt  AVG Time to Throw  AVG  Air Yards Differential  \
# 2                        12.2               2.25                         -2.5
# 3                         0.0               2.67                         -0.6
# 4                         1.0               2.80                         -1.1
# 0                         3.0               2.71                         -5.1
#
#    Aggressiveness  Average Completed Air Yards  Average Intended Air Yards  \
# 2            15.8                          3.7                         6.2
# 3             5.9                          5.1                         5.7
# 4            13.6                          6.8                         7.9
# 0            10.3                          2.7                         7.8
#
#    Longest Completed Air Distance  Air Yards to the Sticks  Passer Rating  \
# 2                            42.3                     -4.1          120.9
# 3                            30.6                     -5.1           67.0
# 4                            54.1                     -0.9          121.3
# 0                            27.0                     -2.0           55.7
#
#    Completion Percentage
# 2                   68.4
# 3                   52.9
# 4                   75.0
# 0                   48.3

# %%
X_test
# Out:
#    Passing Attempts  Passing Completions  Passing Yards  Touchdowns  \
# 1                30                   18            176           2
#
#    Interceptions  Rushing Attempts  Rushing Touchdowns  Rush Yards  \
# 1              0                 2                   0           1
#
#    AVG Rush Yards per Attempt  AVG Time to Throw  AVG  Air Yards Differential  \
# 1                         0.5               2.45                         -1.0
#
#    Aggressiveness  Average Completed Air Yards  Average Intended Air Yards  \
# 1            23.3                          3.7                         4.8
#
#    Longest Completed Air Distance  Air Yards to the Sticks  Passer Rating  \
# 1                            37.8                     -4.2           98.8
#
#    Completion Percentage
# 1                   60.0

# %% [markdown]
# # **Scale the features**

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # **Initialize the RandomForestClassifier**

# %%
model = RandomForestClassifier(n_estimators=5, random_state=100)

# %% [markdown]
# # **Fit Model the training data**

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=5, random_state=100)

# %% [markdown]
# # **Predictions on test set**

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# # **Predict New Fantasy Player**

# %%
5
def predict_fantasy_player():
    # Prompt user to input Player first name
    first_name = input("Enter the player's first name: ")
    #Prompt user to input Player last name
    last_name = input("Enter the player's last name: ")
    #Prompt user to input current week of the season
    current_week = int(input("Enter the current week of the season: "))3
    # Prompt user to input player avg stats
    print("\nEnter the following average stats for the player:")
    input_data = []
    for feature in feature_columns:
        value = float(input(f"{feature}: "))
        input_data.append(value)

    # Convert the input data into a DataFrame and scale it
    input_df = pd.DataFrame([input_data], columns=feature_columns)
    input_scaled = scaler.transform(input_df)

    # Make a prediction
    prediction = model.predict(input_scaled)
    prediction_label = "Boom" if prediction[0] == 1 else "Bust"
    print(f"\nGridiron Genius predicts a {prediction_label}.")

# Call the function to predict for a new player
predict_fantasy_player()
# Out:
# Enter the player's first name: Josh
# Enter the player's last name: Allen
# Enter the current week of the season: 7
#
# Enter the following average stats for the player:
# Passing Attempts: 26.6
# Passing Completions: 16
# Passing Yards: 185.6
# Touchdowns: 1.6
# Interceptions: 0
# Rushing Attempts: 5.2
# Rushing Touchdowns: .2
# Rush Yards: 27.8
# AVG Rush Yards per Attempt: 5.3
# AVG Time to Throw: 2.89
# AVG  Air Yards Differential: -3.7
# Aggressiveness: 16
# Average Completed Air Yards: 5.1
# Average Intended Air Yards: 8.7
# Longest Completed Air Distance: 44
# Air Yards to the Sticks: -0.4
# Passer Rating: 106.8
# Completion Percentage: 62.8
#
# Gridiron Genius predicts a Bust.
