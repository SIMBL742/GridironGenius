# %% [markdown]
# <a href="https://colab.research.google.com/github/SIMBL742/GridironGenius/blob/main/ML_TitansD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Load Data**

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/SIMBL742/GridironGenius/refs/heads/main/dataset_2024-2025_TitansD_QBP_.csv')
df
# Out:
#    Passing Attempts  Passing Completions  Passing Yards  Touchdowns  \
# 0                29                   14             93           0
# 1                30                   18            176           2
# 2                19                   13            202           1
# 3                17                    9             85           0
# 4                38                   22            189           2
#
#    Interceptions  Rushing Attempts  Rushing Touchdowns  Rush Yards  \
# 0              0                 5                   0          15
# 1              0                 2                   0           1
# 2              0                 6                   1          73
# 3              0                 0                   0           0
# 4              1                 1                   0           1
#
#    AVG Rush Yards per Attempt  AVG Time to Throw  AVG  Air Yards Differential  \
# 0                         3.0               2.71                         -5.1
# 1                         0.5               2.45                         -1.0
# 2                        12.2               2.25                         -2.5
# 3                         0.0               2.67                         -0.6
# 4                         1.0               2.80                         -1.1
#
#   Aggressiveness  Average Completed Air Yards  Average Intended Air Yards  \
# 0          10.3%                          2.7                         7.8
# 1          23.3%                          3.7                         4.8
# 2          15.8%                          3.7                         6.2
# 3           5.9%                          5.1                         5.7
# 4          13.6%                          6.8                         7.9
#
#    Longest Completed Air Distance  Air Yards to the Sticks  Passer Rating  \
# 0                            27.0                     -2.0           55.7
# 1                            37.8                     -4.2           98.8
# 2                            42.3                     -4.1          120.9
# 3                            30.6                     -5.1           67.0
# 4                            54.1                     -0.9          121.3
#
#   Completion Percentage  Fantasy Points
# 0                 48.3%            7.22
# 1                 60.0%           15.14
# 2                 68.4%           25.38
# 3                 52.9%           11.84
# 4                 75.0%           14.66

# %% [markdown]
# # **Data Prep**

# %% [markdown]
# ### Data seperation as X and Y

# %%
y=df['Fantasy Points']
y
# Out:
# 0     7.22
# 1    15.14
# 2    25.38
# 3    11.84
# 4    14.66
# Name: Fantasy Points, dtype: float64
